# %%
math=40
pi = 3.14
name ='PM'
print(type(math))
print(type(pi))
print(type(name))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
#type casting
print(5+5)
print("5"+"5")
val = int(input("enter"))
val2 = int(input("enter"))
print(val+val2)
# Out:
# 10
# 55
# 10

# %%
print(int(3.14))
print(int(True))
print(int(False))
print(int("4"))
# Out:
# 3
# 1
# 0
# 4

# %%
print(float(3.14))
print(float(True))
print(float(False))
print(float("4.22"))
# Out:
# 3.14
# 1.0
# 0.0
# 4.22

# %%
print(complex(2))
print(complex(True))
print(complex(False))
# Out:
# (2+0j)
# (1+0j)
# 0j

# %%
print(bool(True))
print(bool(35))
print(bool(0))
# Out:
# True
# True
# False

# %%
#wap for simple interst
#p
p =10000
roi = 10
time =1
SI = p * roi * time/100
print("SI==",SI)
# Out:
# SI== 1000.0

# %%
#wap for centrigrade temp to franhinte
#f=9/5*C+32
T_c=32
T_F=(9/5 * T_c)+32
print(T_F)
# Out:
# 89.6

# %%
v1=21
v2=12
temp =v1
v1 = v2
v2 = temp
print(v1)
print(v2)
# Out:
# 12
# 21

# %%
a=12
b=21
a= a+b
b= a-b
a=a-b
print("a==",a)
print("b==",b)
# Out:
# a== 21
# b== 12

# %%
h_feet=12
h_innch=h_feet*22
h_cm =h_innch*2.24
print(h_innch)
print(h_cm)
# Out:
# 264
# 591.36

# %%
num=123
a=num %10
num = num // 10
print(a)
b=num%10
print(b)
c=num % 10
num = num // 10
rev = a*100+b*10+c*1
print(rev)
# Out:
# 3
# 2
# 322
